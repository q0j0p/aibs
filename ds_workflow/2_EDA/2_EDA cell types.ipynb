# %% [markdown]
# # What are the preexisting neuronal cell type identities?

# %%
import pymongo 
import seaborn as sns
import numpy as np
import collections
import pandas as pd
sns.set()

# %%
client = pymongo.MongoClient('mongodb://localhost/:27017')
db = client.aibs 
print db.collection_names()
# Out:
# [u'nmorpho', u'morphology', u'neurons']

# %%
n_coll = db.neurons
m_coll = db.morphology
nm_coll = db.nmorpho

# %%
print("{} records in neuromorpho collection".format(nm_coll.count()))
print("{} records in morphology collection".format(m_coll.count()))
# Out:
# 20567 records in neuromorpho collection
# 20568 records in morphology collection

# %%
# sample neuromorpho neuron entry 
nm_coll.find_one()
# Out:
# {u'_id': ObjectId('5a99bcfa9d477a4072e45622'),
#  u'_links': {u'measurements': {u'href': u'http://neuromorpho.org/api/morphometry/id/860'},
#   u'self': {u'href': u'http://neuromorpho.org/api/neuron/id/860'}},
#  u'age_classification': u'adult',
#  u'archive': u'Martone',
#  u'attributes': u'Diameter, 3D, Angles',
#  u'brain_region': [u'ventral striatum', u'nucleus accumbens'],
#  u'cell_type': [u'medium spiny', u'principal cell'],
#  u'corrected_value': None,
#  u'corrected_xy': None,
#  u'corrected_z': None,
#  u'deposition_date': u'2005-12-31',
#  u'domain': u'Dendrites, Soma, Axon',
#  u'experiment_condition': u'Control',
#  u'magnification': u'60',
#  u'max_age': u'2.0',
#  u'max_weight': None,
#  u'min_age': u'2.0',
#  u'min_weight': None,
#  u'neuron_id': 860,
#  u'neuron_name': u'ACC1',
#  u'note': u'When originally released, this reconstruction had been incompletely processed, and this issue was fixed in release 6.1 (May 2015). The pre-6.1 version of the processed file is available for download <a href=" dableFiles/previous/v6.1/martone/ACC1.CNG.swc ">here</a>.',
#  u'objective_type': u'water',
#  u'original_format': u'Neurolucida.asc',
#  u'physical_Integrity': u'Dendrites Complete, Axon Incomplete',
#  u'png_url': u'http://neuromorpho.org/images/imageFiles/Martone/ACC1.png',
#  u'protocol': u'in vitro',
#  u'reconstruction_software': u'Neurolucida',
#  u'reference_doi': None,
#  u'reference_pmid': None,
#  u'reported_value': None,
#  u'reported_xy': None,
#  u'reported_z': None,
#  u'scientific_name': u'',
#  u'shrinkage_corrected': u'',
#  u'shrinkage_reported': u'Not reported',
#  u'slicing_direction': u'coronal',
#  u'slicing_thickness': u'100.00',
#  u'soma_surface': u'174.071',
#  u'species': u'mouse',
#  u'stain': u'lucifer yellow',
#  u'strain': u'C57BL/6',
#  u'surface': u'3489.29',
#  u'upload_date': u'2006-08-01',
#  u'volume': u'892.123'}

# %%
# Sample entry in morphology collection 
m_coll.find_one()
# Out:
# {u'_id': ObjectId('5a99bd509d477a4072e4a679'),
#  u'bif_ampl_local': 93.2768,
#  u'branch_Order': 113.0,
#  u'contraction': 0.97921,
#  u'depth': 100.5,
#  u'diameter': 0.554892,
#  u'eucDistance': 93.2874,
#  u'fractal_Dim': 1.05337,
#  u'fragmentation': 1427.0,
#  u'height': 102.321,
#  u'length': 1851.27,
#  u'n_bifs': 394.0,
#  u'n_branch': 793.0,
#  u'n_stems': 5.0,
#  u'neuron_id': 860,
#  u'neuron_name': u'ACC1',
#  u'partition_asymmetry': 0.957281,
#  u'pathDistance': 162.339,
#  u'pk_classic': 1.79627,
#  u'soma_Surface': 174.071,
#  u'surface': 3489.29,
#  u'volume': 892.123,
#  u'width': 66.7084}

# %%
labels = collections.defaultdict(tuple)
for a in nm_coll.find(): 
    labels[a['neuron_id']] = (a['cell_type'],a['age_classification'],a['brain_region'])

# %%
labels.items()[:5]
# Out:
# [(79899,
#   ([u'Glia', u'microglia', u'Iba1-positive'],
#    u'young',
#    [u'basal ganglia', u'striatum'])),
#  (75724, ([u'principal cell', u'pyramidal'], u'embryonic', [u'neocortex'])),
#  (71360, ([u'principal cell', u'pyramidal'], u'embryonic', [u'hippocampus'])),
#  (71142,
#   ([u'principal cell', u'pyramidal'],
#    u'adult',
#    [u'neocortex', u'layer 5', u'left'])),
#  (75943, ([u'principal cell', u'ganglion'], u'adult', [u'retina', u'right']))]

# %%
df = pd.DataFrame(columns = ['neuron_id','cell_type','age_class','brain_region','species'],data=[(a['neuron_id'],a['cell_type'],a['age_classification'],a['brain_region'],a['species']) for a in nm_coll.find({'neuron_id':{'$exists':True}})])

# %%
df.head()
# Out:
#    neuron_id                       cell_type age_class  \
# 0        860  [medium spiny, principal cell]     adult
# 1        862      [Purkinje, principal cell]     adult
# 2        863      [Purkinje, principal cell]     adult
# 3        864      [Purkinje, principal cell]     adult
# 4        865      [Purkinje, principal cell]     adult
#
#                                         brain_region species
# 0              [ventral striatum, nucleus accumbens]   mouse
# 1  [cerebellum, cerebellar cortex, vermis, Purkin...   mouse
# 2  [cerebellum, cerebellar cortex, vermis, Purkin...   mouse
# 3  [cerebellum, cerebellar cortex, vermis, Purkin...   mouse
# 4  [cerebellum, cerebellar cortex, vermis, Purkin...   mouse

# %%
pd.DataFrame(df.cell_type.value_counts())
# Out:
#                                                     cell_type
# [principal cell, pyramidal]                              3296
# [pyramidal, principal cell]                              2731
# [interneuron]                                             603
# [ganglion, principal cell]                                565
# [Glia, microglia, Iba1-positive]                          557
# [medium spiny, principal cell]                            524
# [principal cell, glutamatergic]                           496
# [granule, interneuron]                                    478
# [interneuron, Inhibitory]                                 442
# [principal cell, medium spiny, projection]                440
# [principal cell]                                          391
# [principal cell, granule, adult-born, glutamate...        354
# [principal cell, granule]                                 342
# [sensory receptor]                                        332
# [Glia, astrocyte]                                         321
# [interneuron, bipolar, cone]                              305
# [principal cell, ganglion]                                281
# [granule, principal cell]                                 275
# [Glia]                                                    274
# [Monostratified, ganglion, principal cell]                266
# [principal cell, granule, adult-born]                     261
# [principal cell, medium spiny]                            260
# [adult-born, granule, principal cell]                     215
# [interneuron, Excitatory]                                 208
# [Motoneuron, principal cell]                              207
# [Glia, microglia]                                         202
# [principal cell, pyramidal, complex]                      160
# [newborn, adult-born, granule, principal cell]            157
# [interneuron, amacrine, narrow-field]                     144
# [interneuron, bipolar, rod]                               142
# ...                                                       ...
# [Medial Ganglionic Eminence (MGE)-derived, Regu...          1
# [Neuropeptide Y (NPY)-positive, Cholecystokinin...          1
# [Somatostatin (SOM)-positive, Calretinin (CR)-p...          1
# [Medial Ganglionic Eminence (MGE)-derived, Fast...          1
# [oriens-oriens, interneuron]                                1
# [interneuron, Cajal-Retzius]                                1
# [Regular spiking, Cannabinoid receptor (CB1R)-p...          1
# [oriens-alveus, interneuron]                                1
# [axonless, granule, interneuron]                            1
# [Type I, interneuron-specific interneuron, inte...          1
# [Medial Ganglionic Eminence (MGE)-derived, Late...          1
# [Medial Ganglionic Eminence (MGE)-derived, Late...          1
# [Chicken ovalbumin upstream promoter transcript...          1
# [Somatostatin (SOM)-positive, Medial Ganglionic...          1
# [Cholecystokinin (CCK)-positive, Regular spikin...          1
# [Cholecystokinin (CCK)-positive, Regular spikin...          1
# [Chicken ovalbumin upstream promoter transcript...          1
# [Cholecystokinin (CCK)-positive, Caudal Ganglio...          1
# [Vesicular glutamate transporter type 3 (VGluT3...          1
# [Parvalbumin (PV)-positive, Calretinin (CR)-pos...          1
# [Chicken ovalbumin upstream promoter transcript...          1
# [Parvalbumin (PV)-positive, Calretinin (CR)-pos...          1
# [Neuronal Nitric Oxide Synthase (nNOS)-positive...          1
# [Somatostatin (SOM)-positive, Medial Ganglionic...          1
# [Neuropeptide Y (NPY)-positive, Medial Ganglion...          1
# [Cholecystokinin (CCK)-positive, Neuropeptide Y...          1
# [Medial Ganglionic Eminence (MGE)-derived, Late...          1
# [Neuropeptide Y (NPY)-positive, Parvalbumin (PV...          1
# [Medial Ganglionic Eminence (MGE)-derived, Late...          1
# [GABAergic, HICAP, interneuron]                             1
#
# [396 rows x 1 columns]

# %%
pd.DataFrame(df.brain_region.value_counts())
# Out:
#                                                     brain_region
# [retina]                                                    1638
# [hippocampus, dentate gyrus, granule layer]                 1520
# [neocortex]                                                 1027
# [retina, ganglion layer]                                     949
# [spinal cord, lumbar, dorsal horn, low-threshol...           650
# [neocortex, frontal, layer 3]                                634
# [hippocampus]                                                582
# [hippocampus, CA1]                                           576
# [peripheral nervous system, dorsal root ganglion]            482
# [neocortex, somatosensory, layer 4]                          453
# [basal ganglia, ventral striatum, nucleus accum...           440
# [neocortex, anterior cingulate, layer 3]                     435
# [neocortex, somatosensory]                                   416
# [main olfactory bulb]                                        402
# [spinal cord, lumbar, ventral horn]                          396
# [neocortex, somatosensory, barrel, layer 6]                  377
# [basal ganglia, striatum, dorsomedial]                       374
# [basal ganglia, striatum]                                    373
# [neocortex, medial prefrontal, layer 2-3]                    331
# [hippocampus, dentate gyrus, molecular layer]                325
# [hippocampus, CA1, stratum pyramidale, dorsal]               301
# [hippocampus, dentate gyrus]                                 293
# [neocortex, Multiple]                                        274
# [neocortex, frontal, layer 5]                                243
# [neocortex, occipital, primary visual, layer 5]              231
# [neocortex, occipital]                                       209
# [neocortex, somatosensory, layer 2-3]                        202
# [neocortex, prefrontal]                                      202
# [neocortex, occipital, primary visual, layer 2-3]            184
# [hippocampus, CA3]                                           182
# ...                                                          ...
# [neocortex, primary auditory, layer 5]                         1
# [myelencephalon, inferior olive, left]                         1
# [neocortex, occipital, primary visual, layer 3-4]              1
# [neocortex, somatosensory, primary somatosensor...             1
# [hippocampus, dentate gyrus, dorsal, molecular ...             1
# [neocortex, layer 2]                                           1
# [neocortex, presubiculum, layer 4]                             1
# [hippocampus, CA1, inner]                                      1
# [hippocampus, CA3, inner]                                      1
# [spinal cord, L5-L6, ventral horn]                             1
# [hippocampus, CA1, pyramidal layer, outer]                     1
# [neocortex, occipital, anteromedial visual, lay...             1
# [neocortex, occipital, anterolateral visual, la...             1
# [neocortex, frontal, primary motor, layer 6]                   1
# [hippocampus, CA1, CA1c, stratum radiatum]                     1
# [hippocampus, CA1, CA1c, inner]                                1
# [hippocampus, CA3, stratum lacunosum-moleculare]               1
# [neocortex, somatosensory, barrel, A1, layer 5-6]              1
# [accessory olfactory bulb, mitral layer]                       1
# [neocortex, somatosensory, barrel, A4, layer 5-6]              1
# [hippocampus, dentate gyrus, granule layer, outer]             1
# [neocortex, somatosensory, barrel, E2, layer 5-6]              1
# [neocortex, somatosensory, barrel, E4, layer 5-6]              1
# [hippocampus, dentate gyrus, dorsal, granule la...             1
# [anterior olfactory nucleus, pars principalis, ...             1
# [amygdala, basolateral amygdala complex, basal ...             1
# [neocortex, somatosensory, barrel, layer 5]                    1
# [neocortex, somatosensory, barrel, layer 2]                    1
# [neocortex, somatosensory, barrel, layer 1]                    1
# [anterior olfactory nucleus, pars principalis, ...             1
#
# [267 rows x 1 columns]

# %%
pd.DataFrame(df.age_class.value_counts())
# Out:
#               age_class
# adult             10094
# young              4338
# young adult        2766
# embryonic          1230
# not reported       1206
# neonatal            553
# old                 378
# fetus                 2

# %% [markdown]
# ## Cell type observations
# Cells aren't tightly labeled.  Need to look into the latest in ontology representations
