# %% [markdown]
# # Scrape Drosophila swc data from neuromorpho.org
#
# ### Neuromorpho
# Neuromorpho.org is a jsp website.
# Scrape and download using selenium.

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys 
sys.path.append('../')

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from bs4 import BeautifulSoup as BS
import time
from src import neuroncollector

# %%
# initialize scraper
scraper = neuroncollector.NeuroScraper()
# Out:
# Connected to mongodb://localhost:27017/
# absolute path to project root directory: /Users/User1/DS/aibs/
# <selenium.webdriver.firefox.firefox_profile.FirefoxProfile object at 0x12eade8d0>

# %%
scraper.get_neuromorpho_species_swc_files()
# Out:
# Total number of species: 40
# Species names
# 0 agouti
# 1 Baboon
# 2 Blind
# 3 blowfly
# 4 bottlenose
# 5 C.
# 6 cat
# 7 chicken
# 8 chimpanzee
# 9 clouded
# 10 Crab
# 11 cricket
# 12 domestic
# 13 dragonfly
# 14 drosophila
# 15 elephant
# 16 giraffe
# 17 goldfish
# 18 guinea
# 19 Hamster
# 20 human
# 21 humpback
# 22 locust
# 23 manatee
# 24 minke
# 25 monkey
# 26 moth
# 27 mouse
# 28 pouched
# 29 proechimys
# 30 rabbit
# 31 Rana
# 32 rat
# 33 salamander
# 34 sheep
# 35 spiny
# 36 Tiger
# 37 turtle
# 38 Xenopus
# 39 zebrafish
# clicking on drosophila
# Source names (count:0):
# Source names (count:18):
# 0 drosophila melanogasterBorst
# 1 drosophila melanogasterCardona
# 2 drosophila melanogasterChiang
# 3 drosophila melanogasterChklovskii
# 4 drosophila melanogasterCirelli
# 5 drosophila melanogasterCox
# 6 drosophila melanogasterDrago
# 7 drosophila melanogasterFlyEM
# 8 drosophila melanogasterJan
# 9 drosophila melanogasterJefferis
# 10 drosophila melanogasterLandgraf
# 11 drosophila melanogasterLee_CH
# 12 drosophila melanogasterOlesnicky
# 13 drosophila melanogasterRybak_Knaden
# 14 drosophila melanogastervanderVoet_Castells
# 15 drosophila melanogasterYe
# 16 drosophila melanogasterChiang,Peng
# 17 drosophila melanogasterJefferis,DIADEM
# Clicked 'include aux files'
# ['drosophila melanogasterBorstoptic Lobe']
# 0 - Clicking on drosophila melanogasterBorstoptic Lobe
# ['drosophila melanogasterCardonaperipheral nervous system']
# 1 - Clicking on drosophila melanogasterCardonaperipheral nervous system
# ['drosophila melanogasterChiangadult central complex', 'drosophila melanogasterChiangadult subesophageal zone', 'drosophila melanogasterChiangantennal lobe', 'drosophila melanogasterChianglateral complex', 'drosophila melanogasterChianglateral horn', 'drosophila melanogasterChiangLeft Mushroom Body', 'drosophila melanogasterChiangoptic Lobe', 'drosophila melanogasterChiangprotocerebrum', 'drosophila melanogasterChiangRight Mushroom Body', 'drosophila melanogasterChiangsubesophageal ganglion', 'drosophila melanogasterChiangventrolateral neuropils']
# 2 - Clicking on drosophila melanogasterChiangadult central complex
# 2 - Clicking on drosophila melanogasterChiangadult subesophageal zone
# 2 - Clicking on drosophila melanogasterChiangantennal lobe
# 2 - Clicking on drosophila melanogasterChianglateral complex
# 2 - Clicking on drosophila melanogasterChianglateral horn
# 2 - Clicking on drosophila melanogasterChiangLeft Mushroom Body
# 2 - Clicking on drosophila melanogasterChiangoptic Lobe
# 2 - Clicking on drosophila melanogasterChiangprotocerebrum
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-56-121e2d7ef05b> in <module>()
# ----> 1 scraper.get_neuromorpho_species_swc_files()
#
# ~/DS/aibs/src/neuroncollector.py in get_neuromorpho_species_swc_files(self, include_signature, include_aux, species_index)
#     156                 self.driver.switch_to.window(self.driver.window_handles[1])
#     157                 time.sleep(10)
# --> 158                 self.driver.find_element_by_name('yes').click()
#     159                 time.sleep(20)
#     160                 self.driver.close()
#
# ~/anaconda/envs/python3/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in find_element_by_name(self, name)
#     485             element = driver.find_element_by_name('foo')
#     486         """
# --> 487         return self.find_element(by=By.NAME, value=name)
#     488
#     489     def find_elements_by_name(self, name):
#
# ~/anaconda/envs/python3/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#     953         return self.execute(Command.FIND_ELEMENT, {
#     954             'using': by,
# --> 955             'value': value})['value']
#     956
#     957     def find_elements(self, by=By.ID, value=None):
#
# ~/anaconda/envs/python3/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     310         response = self.command_executor.execute(driver_command, params)
#     311         if response:
# --> 312             self.error_handler.check_response(response)
#     313             response['value'] = self._unwrap_value(
#     314                 response.get('value', None))
#
# ~/anaconda/envs/python3/lib/python3.6/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: Unable to locate element: [name="yes"]

# %%
# optionally get the entire page for parsing and soupify
soup = BS(scraper.driver.page_source, "html.parser")

# get list of data sources
datasources = soup.findAll("font", {"class": "lvl2"})
source_name = [a.text for a in datasources]

# `lvl3` is label for brain regions
brain_region = soup.findAll("font", {"class": "lvl3"})

set([a.text for a in brain_region])

#Neuron cell types!  
cell_types = soup.findAll("font", {"class": "lvl4"})

set([a.text for a in cell_types])  

# individual neuron ids
neurons = soup.findAll("a", {"class": "screenshot"})

# Number of neurons
len(neurons)
